# %% [markdown]
# ### Files in the folder

# %%
import pandas as pd
from pathlib import Path

# Folder containing the CSV files
folder_path = Path(r'E:\\Power BI\\Health Care Dashboard\\Health-Care\\data\\Inpatient\\')

# Read all CSV files
for file in folder_path.glob("*.csv"):
    print(f"\n{file.name}")
# Out:
# inpatient_data.csv
#
# IN_WL 2018.csv
#
# IN_WL 2019.csv
#
# IN_WL 2020.csv
#
# IN_WL 2021.csv

# %% [markdown]
# ### Reading the 1st file

# %%
import pandas as pd
df = pd.read_csv(r'E:\\Power BI\\Health Care Dashboard\\Health-Care\\data\\Inpatient\\IN_WL 2018.csv')
# Remove any 'Unnamed' columns
df = df.loc[:, ~df.columns.str.startswith("Unnamed")]
df.head(5)

for col in df.columns:
    print(col)
# Out:
# Archive_Date
# Specialty_HIPE
# Specialty_Name
# Case_Type
# Adult_Child
# Age_Profile
# Time_Bands
# Total

# %%
import pandas as pd
df = pd.read_csv(r'E:\\Power BI\\Health Care Dashboard\\Health-Care\\data\\Inpatient\\IN_WL 2019.csv')
# Remove any 'Unnamed' columns
df = df.loc[:, ~df.columns.str.startswith("Unnamed")]
df.head(5)

for col in df.columns:
    print(col)
# Out:
# Archive_Date
# Specialty_HIPE
# Specialty_Name
# Case_Type
# Adult_Child
# Age_Profile
# Time_Bands
# Total

# %%
import pandas as pd
df = pd.read_csv(r'E:\\Power BI\\Health Care Dashboard\\Health-Care\\data\\Inpatient\\IN_WL 2020.csv')
# Remove any 'Unnamed' columns
df = df.loc[:, ~df.columns.str.startswith("Unnamed")]
df.head(5)

for col in df.columns:
    print(col)
# Out:
# Archive_Date
# Specialty_HIPE
# Specialty_Name
# Case_Type
# Adult_Child
# Age_Profile
# Time_Bands
# Total

# %%
import pandas as pd
df = pd.read_csv(r'E:\\Power BI\\Health Care Dashboard\\Health-Care\\data\\Inpatient\\IN_WL 2021.csv')
# Remove any 'Unnamed' columns
df = df.loc[:, ~df.columns.str.startswith("Unnamed")]
df.head(5)

for col in df.columns:
    print(col)
# Out:
# Archive_Date
# Specialty_HIPE
# Specialty_Name
# Case_Type
# Adult_Child
# Age_Profile
# Time_Bands
# Total

# %%
import pandas as pd
from pathlib import Path

# Folder containing the CSV files
folder_path = Path(r'E:\\Power BI\\Health Care Dashboard\\Health-Care\\data\\Inpatient\\')

# Read all CSV files
for file in folder_path.glob("*.csv"):

    # Read only the header
    df = pd.read_csv(file, nrows=0)

    # Remove any 'Unnamed' columns
    df = df.loc[:, ~df.columns.str.startswith("Unnamed")]

    print(f"\n{file.name}")
    print("-" * len(file.name))

    for column in df.columns:
        print(column)
# Out:
# IN_WL 2018.csv
# --------------
# Archive_Date
# Specialty_HIPE
# Specialty_Name
# Case_Type
# Adult_Child
# Age_Profile
# Time_Bands
# Total
#
# IN_WL 2019.csv
# --------------
# Archive_Date
# Specialty_HIPE
# Specialty_Name
# Case_Type
# Adult_Child
# Age_Profile
# Time_Bands
# Total
#
# IN_WL 2020.csv
# --------------
# Archive_Date
# Specialty_HIPE
# Specialty_Name
# Case_Type
# Adult_Child
# Age_Profile
# Time_Bands
# Total
#
# IN_WL 2021.csv
# --------------
# Archive_Date
# Specialty_HIPE
# Specialty_Name
# Case_Type
# Adult_Child
# Age_Profile
# Time_Bands
# Total
