# %%
import pandas as pd
df = pd.read_csv(r'E:\Power BI\Health Care Dashboard\Health-Care\data\merged_data\inpatient_data.csv')
#df.head(5)
shape = df.shape
print(f"The shape of the DataFrame is: {shape}")
# Out:
# The shape of the DataFrame is: (182136, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 182136 entries, 0 to 182135
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Archive_Date    182136 non-null  str
#  1   Specialty_HIPE  182136 non-null  int64
#  2   Specialty_Name  182136 non-null  str
#  3   Case_Type       182136 non-null  str
#  4   Adult_Child     182136 non-null  str
#  5   Age_Profile     182136 non-null  str
#  6   Time_Bands      182136 non-null  str
#  7   Total           182136 non-null  int64
# dtypes: int64(2), str(6)
# memory usage: 11.1 MB
