# %% [markdown]
# ## Analyzing Mapping Speciality File

# %%
import pandas as pd

df = pd.read_csv(r"E:\Power BI\Health Care Dashboard\Health-Care\data\Mapping_Specialty.csv")
df.head(5)
# Out:
#                      Specialty Specialty Group
# 0                 Anaesthetics     Respiratory
# 1                   Cardiology           Heart
# 2      Cardio-Thoracic Surgery           Heart
# 3  Child/Adolescent Psychiatry       Psychatry
# 4  Clinical (Medical) Genetics           Genes

# %%
df.shape
# Out:
# (78, 2)

# %%
print(f"Rows    : {df.shape[0]:,}")
# Out:
# Rows    : 78

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Specialty        78 non-null     str
#  1   Specialty Group  78 non-null     str
# dtypes: str(2)
# memory usage: 1.3 KB

# %%
df["Specialty"].value_counts()
# Out:
# Specialty
# Anaesthetics                   1
# Cardiology                     1
# Cardio-Thoracic Surgery        1
# Child/Adolescent Psychiatry    1
# Clinical (Medical) Genetics    1
#                               ..
# Microbiology                   1
# Substance Abuse                1
# Occupational Medicine          1
# Accident & Emergency           1
# Intensive Care                 1
# Name: count, Length: 78, dtype: int64

# %%
counts = df.groupby("Specialty").size()
print(counts[counts > 1])
#if there is no output then there are no duplicates in the Specialty column
# Out:
# Series([], dtype: int64)

# %%
print(f"Rows: {len(df)}")
print(f"Unique Specialty: {df['Specialty'].nunique()}")
# If the value appears to be same,  then there are no duplicates in the Specialty column
# Out:
# Rows: 78
# Unique Specialty: 78
